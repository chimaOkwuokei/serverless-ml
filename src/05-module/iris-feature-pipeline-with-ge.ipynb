# %% [markdown]
# # Iris Flower - Feature Pipeline
#
# In this notebook we will,
#
# 1. Run in either "Backfill" or "Normal" operation.
# 2. IF *BACKFILL==True*, we will load our DataFrame with data from the iris.csv file
#
#    ELSE *BACKFILL==False*, we will load our DataFrame with one synthetic Iris Flower sample
# 3. Write our DataFrame to a Feature Group

# %%
# !pip install -U hopsworks --quiet

# %%
# !pip install great_expectations
# Out:
# Collecting great_expectations
#   Downloading great_expectations-1.3.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<5.0.0,>=4.2.1 (from great_expectations)
#   Downloading altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cryptography>=3.2 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (42.0.2)
# Requirement already satisfied: jinja2>=2.10 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (4.19.2)
# Collecting marshmallow<4.0.0,>=3.7.1 (from great_expectations)
#   Downloading marshmallow-3.23.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.0.4)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (23.1)
# Collecting posthog<3,>=2.1.0 (from great_expectations)
#   Downloading posthog-2.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pydantic>=1.10.7 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.10.3)
# Requirement already satisfied: pyparsing>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: requests>=2.20 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.31.0)
# Requirement already satisfied: ruamel.yaml>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (0.17.21)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (1.11.4)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (4.12.2)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.3.0 in c:\users\hp\anaconda3\lib\site-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in c:\users\hp\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in c:\users\hp\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\anaconda3\lib\site-packages (from cryptography>=3.2->great_expectations) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2>=2.10->great_expectations) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.10.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from posthog<3,>=2.1.0->great_expectations) (1.16.0)
# Collecting monotonic>=1.5 (from posthog<3,>=2.1.0->great_expectations)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog<3,>=2.1.0->great_expectations)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.59.0->great_expectations) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Downloading great_expectations-1.3.0-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.0 MB 660.6 kB/s eta 0:00:08
#    ---------------------------------------- 0.0/5.0 MB 660.6 kB/s eta 0:00:08
#    ---------------------------------------- 0.1/5.0 MB 365.7 kB/s eta 0:00:14
#     --------------------------------------- 0.1/5.0 MB 476.3 kB/s eta 0:00:11
#     --------------------------------------- 0.1/5.0 MB 481.4 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/5.0 MB 532.5 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/5.0 MB 532.5 kB/s eta 0:00:10
#    - -------------------------------------- 0.2/5.0 MB 456.4 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/5.0 MB 454.0 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/5.0 MB 454.0 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/5.0 MB 430.1 kB/s eta 0:00:12
#    - -------------------------------------- 0.2/5.0 MB 424.3 kB/s eta 0:00:12
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.3/5.0 MB 437.3 kB/s eta 0:00:11
#    --- ------------------------------------ 0.4
#    ---------------------------------- ---- 727.0/813.6 kB 27.1 kB/s eta 0:00:04
#    ----------------------------------- --- 747.5/813.6 kB 27.5 kB/s eta 0:00:03
#    ----------------------------------- --- 747.5/813.6 kB 27.5 kB/s eta 0:00:03
#    ------------------------------------ -- 757.8/813.6 kB 27.7 kB/s eta 0:00:03
#    ------------------------------------ -- 757.8/813.6 kB 27.7 kB/s eta 0:00:03
#    ------------------------------------ -- 757.8/813.6 kB 27.7 kB/s eta 0:00:03
#    ------------------------------------- - 778.2/813.6 kB 28.3 kB/s eta 0:00:02
#    ------------------------------------- - 778.2/813.6 kB 28.3 kB/s eta 0:00:02
#    ------------------------------------- - 788.5/813.6 kB 28.5 kB/s eta 0:00:01
#    --------------------------------------  798.7/813.6 kB 28.9 kB/s eta 0:00:01
#    --------------------------------------  798.7/813.6 kB 28.9 kB/s eta 0:00:01
#    --------------------------------------  809.0/813.6 kB 29.1 kB/s eta 0:00:01
#    --------------------------------------- 813.6/813.6 kB 29.2 kB/s eta 0:00:00
# Downloading marshmallow-3.23.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/49.3 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/49.3 kB ? eta -:--:--
#    ------------------------ --------------- 30.7/49.3 kB 187.9 kB/s eta 0:00:01
#    ------------------------ --------------- 30.7/49.3 kB 187.9 kB/s eta 0:00:01
#    ------------------------ --------------- 30.7/49.3 kB 187.9 kB/s eta 0:00:01
#    --------------------------------- ------ 41.0/49.3 kB 98.5 kB/s eta 0:00:01
#    ---------------------------------------- 49.3/49.3 kB 100.2 kB/s eta 0:00:00
# Downloading posthog-2.5.0-py2.py3-none-any.whl (36 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: monotonic, marshmallow, backoff, posthog, altair, great_expectations
#   Attempting uninstall: altair
#     Found existing installation: altair 5.0.1
#     Uninstalling altair-5.0.1:
#       Successfully uninstalled altair-5.0.1
# Successfully installed altair-4.2.2 backoff-2.2.1 great_expectations-1.3.0 marshmallow-3.23.2 monotonic-1.6 posthog-2.5.0

# %% [markdown]
# Set **BACKFILL=True** if you want to create features from the iris.csv file containing historical data.

# %%
import random
import pandas as pd
import hopsworks

BACKFILL=True

# %% [markdown]
# ### Synthetic Data Functions
#
# These synthetic data functions can be used to create a DataFrame containing a single Iris Flower sample.

# %%
def generate_flower(name, sepal_len_max, sepal_len_min, sepal_width_max, sepal_width_min, 
                    petal_len_max, petal_len_min, petal_width_max, petal_width_min):
    """
    Returns a single iris flower as a single row in a DataFrame
    """
    df = pd.DataFrame({ "sepal_length": [random.uniform(sepal_len_max, sepal_len_min)],
                       "sepal_width": [random.uniform(sepal_width_max, sepal_width_min)],
                       "petal_length": [random.uniform(petal_len_max, petal_len_min)],
                       "petal_width": [random.uniform(petal_width_max, petal_width_min)]
                      })
    df['variety'] = name
    return df


def get_random_iris_flower():
    """
    Returns a DataFrame containing one random iris flower
    """
    virginica_df = generate_flower("Virginica", 8, 5.5, 3.8, 2.2, 7, 4.5, 2.5, 1.4)
    versicolor_df = generate_flower("Versicolor", 7.5, 4.5, 3.5, 2.1, 5.5, 3.1, 1.8, 1.0)
    setosa_df =  generate_flower("Setosa", 6, 4.5, 4.5, 2.3, 2, 1.2, 0.7, 0.3)

    # randomly pick one of these 3 and write it to the featurestore
    pick_random = random.uniform(0,3)
    if pick_random >= 2:
        iris_df = virginica_df
    elif pick_random >= 1:
        iris_df = versicolor_df
    else:
        iris_df = setosa_df

    return iris_df

# %% [markdown]
# ## Backfill or create new synthetic input data
#
# You can run this pipeline in either *backfill* or *synthetic-data* mode.

# %%
if BACKFILL == True:
    iris_df = pd.read_csv("https://repo.hops.works/master/hopsworks-tutorials/data/iris.csv")
else:
    iris_df = get_random_iris_flower()
    iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
import great_expectations as ge
# from great_expectations.expectations.expectation_configuration import ExpectationConfiguration

# Create an ExpectationSuite with a name
expectation_suite = ge.core.ExpectationSuite(name="iris_dimensions")

# Function to add an expectation to the suite
def value_between(expectation_suite, column_name, min_value, max_value):
    expectation = ge.expectations.expectation_configuration.ExpectationConfiguration(
        type= "expect_column_values_to_be_between",
        kwargs= {
            "column": column_name,
            "min_value": min_value,
            "max_value": max_value,
            },
     )
    # Append the expectation to the suite
    expectation_suite.expectations.append(expectation)

    
# Add expectations
value_between(expectation_suite, "sepal_length", 4.3, 8.0)
value_between(expectation_suite, "sepal_width", 2.0, 4.5)
value_between(expectation_suite, "petal_length", 1.0, 7.0)
value_between(expectation_suite, "petal_width", 0.1, 4.5)

# %% [markdown]
# ## Authenticate with Hopsworks using your API Key
#
# Hopsworks will prompt you to paste in your API key and provide you with a link to find your API key if you have not stored it securely already.

# %%
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# 2024-12-27 13:50:34,531 INFO: Initializing external client
# 2024-12-27 13:50:34,532 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2024-12-27 13:50:39,761 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1207459

# %% [markdown]
# ## Create and write to a feature group - primary keys
#
# To prevent duplicate entries, Hopsworks requires that each DataFame has a *primary_key*.
# A *primary_key* is one or more columns that uniquely identify the row. Here, we assume
# that each Iris flower has a unique combination of ("sepal_length","sepal_width","petal_length","petal_width")
# feature values. If you randomly generate a sample that already exists in the feature group, the insert operation will fail.
#
# The *feature group* will create its online schema using the schema of the Pandas DataFame.

# %%
iris_fg = fs.get_or_create_feature_group(name="iris",
                                  version=7,
                                  primary_key=["sepal_length","sepal_width","petal_length","petal_width"],
                                  description="Iris flower dataset",
                                  expectation_suite=expectation_suite
                                 )
# Out:
# ---------------------------------------------------------------------------
# RestAPIError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\hsfs\feature_store.py:807, in FeatureStore.get_or_create_feature_group(self, name, version, description, online_enabled, time_travel_format, partition_key, primary_key, embedding_index, hudi_precombine_key, features, statistics_config, expectation_suite, event_time, stream, parents, topic_name, notification_topic_name, transformation_functions, online_config, offline_backfill_every_hr, storage_connector, path)
#     806 try:
# --> 807     feature_group_object = self._feature_group_api.get(self.id, name, version)
#     808     feature_group_object.feature_store = self
#
# File ~\anaconda3\Lib\site-packages\hsfs\core\feature_group_api.py:110, in FeatureGroupApi.get(self, feature_store_id, name, version)
#     108 # In principle unique names are enforced across fg type and this should therefore
#     109 # return only list of the same type. But it cost nothing to check in case this gets forgotten.
# --> 110 for fg_json in _client._send_request("GET", path_params, query_params):
#     111     if (
#     112         fg_json["type"] == FeatureGroupApi.BACKEND_FG_STREAM
#     113         or fg_json["type"] == FeatureGroupApi.BACKEND_FG_BATCH
#     114     ):
#
# File ~\anaconda3\Lib\site-packages\hopsworks_common\decorators.py:45, in connected.<locals>.if_connected(inst, *args, **kwargs)
#      44     raise NoHopsworksConnectionError
# ---> 45 return fn(inst, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\hopsworks_common\client\base.py:186, in Client._send_request(self, method, path_params, query_params, headers, data, stream, files, with_base_path_params)
#     185 if response.status_code // 100 != 2:
# --> 186     raise exceptions.RestAPIError(url, response)
#     188 if stream:
#
# RestAPIError: Metadata operation error: (url: https://c.app.hopsworks.ai/hopsworks-api/api/project/1207459/featurestores/1195092/featuregroups/iris). Server response:
# HTTP code: 404, HTTP reason: Not Found, body: b'{"errorCode":270009,"usrMsg":"feature group name: iris feature group version: 7","errorMsg":"Featuregroup wasn\'t found."}', error code: 270009, error msg: Featuregroup wasn't found., user msg: feature group name: iris feature group version: 7
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 iris_fg = fs.get_or_create_feature_group(name="iris",
#       2                                   version=7,
#       3                                   primary_key=["sepal_length","sepal_width","petal_length","petal_width"],
#       4                                   description="Iris flower dataset",
#       5                                   expectation_suite=expectation_suite
#       6                                  )
#
# File ~\anaconda3\Lib\site-packages\hopsworks_common\usage.py:246, in method_logger.<locals>.wrapper(*args, **kwargs)
#     244 except Exception as e:
#     245     exception = e
# --> 246     raise e
#     247 finally:
#     248     try:
#
# File ~\anaconda3\Lib\site-packages\hopsworks_common\usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\hsfs\feature_store.py:815, in FeatureStore.get_or_create_feature_group(self, name, version, description, online_enabled, time_travel_format, partition_key, primary_key, embedding_index, hudi_precombine_key, features, statistics_config, expectation_suite, event_time, stream, parents, topic_name, notification_topic_name, transformation_functions, online_config, offline_backfill_every_hr, storage_connector, path)
#     810 except exceptions.RestAPIError as e:
#     811     if (
#     812         e.response.json().get("errorCode", "") == 270009
#     813         and e.response.status_code == 404
#     814     ):
# --> 815         feature_group_object = feature_group.FeatureGroup(
#     816             name=name,
#     817             version=version,
#     818             description=description,
#     819             online_enabled=online_enabled,
#     820             time_travel_format=time_travel_format,
#     821             partition_key=partition_key or [],
#     822             primary_key=primary_key or [],
#     823             embedding_index=embedding_index,
#     824             hudi_precombine_key=hudi_precombine_key,
#     825             featurestore_id=self._id,
#     826             featurestore_name=self._name,
#     827             features=features or [],
#     828             statistics_config=statistics_config,
#     829             event_time=event_time,
#     830             stream=stream,
#     831             expectation_suite=expectation_suite,
#     832             parents=parents or [],
#     833             topic_name=topic_name,
#     834             notification_topic_name=notification_topic_name,
#     835             transformation_functions=transformation_functions,
#     836             online_config=online_config,
#     837             offline_backfill_every_hr=offline_backfill_every_hr,
#     838             storage_connector=storage_connector,
#     839             path=path,
#     840         )
#     841         feature_group_object.feature_store = self
#     842         return feature_group_object
#
# File ~\anaconda3\Lib\site-packages\hsfs\feature_group.py:2262, in FeatureGroup.__init__(self, name, version, featurestore_id, description, partition_key, primary_key, hudi_precombine_key, featurestore_name, embedding_index, created, creator, id, features, location, online_enabled, time_travel_format, statistics_config, online_topic_name, topic_name, notification_topic_name, event_time, stream, expectation_suite, parents, href, delta_streamer_job_conf, deprecated, transformation_functions, online_config, offline_backfill_every_hr, storage_connector, path, **kwargs)
#    2211 def __init__(
#    2212     self,
#    2213     name: str,
#    (...)
#    2260     **kwargs,
#    2261 ) -> None:
# -> 2262     super().__init__(
#    2263         name,
#    2264         version,
#    2265         featurestore_id,
#    2266         location,
#    2267         event_time=event_time,
#    2268         online_enabled=online_enabled,
#    2269         embedding_index=embedding_index,
#    2270         id=id,
#    2271         expectation_suite=expectation_suite,
#    2272         online_topic_name=online_topic_name,
#    2273         topic_name=topic_name,
#    2274         notification_topic_name=notification_topic_name,
#    2275         deprecated=deprecated,
#    2276         online_config=online_config,
#    2277         storage_connector=storage_connector,
#    2278         path=path,
#    2279     )
#    2280     self._feature_store_name: Optional[str] = featurestore_name
#    2281     self._description: Optional[str] = description
#
# File ~\anaconda3\Lib\site-packages\hsfs\feature_group.py:175, in FeatureGroupBase.__init__(self, name, version, featurestore_id, location, event_time, online_enabled, id, embedding_index, expectation_suite, online_topic_name, topic_name, notification_topic_name, deprecated, online_config, storage_connector, path, **kwargs)
#     173 self._embedding_index = embedding_index
#     174 # use setter for correct conversion
# --> 175 self.expectation_suite = expectation_suite
#     177 self._feature_group_engine: Optional[
#     178     feature_group_engine.FeatureGroupEngine
#     179 ] = None
#     180 self._statistics_engine: statistics_engine.StatisticsEngine = (
#     181     statistics_engine.StatisticsEngine(featurestore_id, self.ENTITY_TYPE)
#     182 )
#
# File ~\anaconda3\Lib\site-packages\hsfs\feature_group.py:2043, in FeatureGroupBase.expectation_suite(self, expectation_suite)
#    2041     self._expectation_suite = None
#    2042 else:
# -> 2043     raise TypeError(
#    2044         "The argument `expectation_suite` has to be `None` of type `ExpectationSuite` or `dict`, but is of type: `{}`".format(
#    2045             type(expectation_suite)
#    2046         )
#    2047     )
#
# TypeError: The argument `expectation_suite` has to be `None` of type `ExpectationSuite` or `dict`, but is of type: `<class 'great_expectations.core.expectation_suite.ExpectationSuite'>`

# %%
iris_fg.insert(iris_df, write_options={"wait_for_job" : False})

#iris_fg.delete_expectation_suite()
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/398/fs/335/fg/8606
# 2022-12-19 19:34:59,891 INFO: 	4 expectation(s) included in expectation_suite.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/398/fs/335/fg/8606
# Uploading Dataframe: 0.00% |          | Rows 0/150 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching offline feature group backfill job...
# Backfill Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/398/jobs/named/iris_7_offline_fg_backfill/executions
# (<hsfs.core.job.Job at 0x7f1e733ef2b0>,
#  {
#    "evaluation_parameters": {},
#    "success": true,
#    "statistics": {
#      "evaluated_expectations": 4,
#      "successful_expectations": 4,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "results": [
#      {
#        "expectation_config": {
#          "expectation_type": "expect_column_values_to_be_between",
#          "meta": {
#            "expectationId": 7213
#          },
#          "kwargs": {
#            "column": "petal_width",
#            "min_value": 0.1,
#            "max_value": 4.5
#          }
#        },
#        "success": true,
#        "result": {
#          "element_count": 150,
#          "missing_count": 0,
#          "missing_percent": 0.0,
#          "unexpected_count": 0,
#          "unexpected_percent": 0.0,
#          "unexpected_percent_total": 0.0,
#          "unexpected_percent_nonmissing": 0.0,
#          "partial_unexpected_list": []
#        },
#        "meta": {},
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      },
#      {
#        "expectation_config": {
#          "expectation_type": "expect_column_values_to_be_between",
#          "meta": {
#            "expectationId": 7214
#          },
#          "kwargs": {
#            "column": "sepal_length",
#            "min_value": 4.3,
#            "max_value": 8.0
#          }
#        },
#        "success": true,
#        "result": {
#          "element_count": 150,
#          "missing_count": 0,
#          "missing_percent": 0.0,
#          "unexpected_count": 0,
#          "unexpected_percent": 0.0,
#          "unexpected_percent_total": 0.0,
#          "unexpected_percent_nonmissing": 0.0,
#          "partial_unexpected_list": []
#        },
#        "meta": {},
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      },
#      {
#        "expectation_config": {
#          "expectation_type": "expect_column_values_to_be_between",
#          "meta": {
#            "expectationId": 7215
#          },
#          "kwargs": {
#            "column": "petal_length",
#            "min_value": 1.0,
#            "max_value": 7
#          }
#        },
#        "success": true,
#        "result": {
#          "element_count": 150,
#          "missing_count": 0,
#          "missing_percent": 0.0,
#          "unexpected_count": 0,
#          "unexpected_percent": 0.0,
#          "unexpected_percent_total": 0.0,
#          "unexpected_percent_nonmissing": 0.0,
#          "partial_unexpected_list": []
#        },
#        "meta": {},
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      },
#      {
#        "expectation_config": {
#          "expectation_type": "expect_column_values_to_be_between",
#          "meta": {
#            "expectationId": 7212
#          },
#          "kwargs": {
#            "column": "sepal_width",
#            "min_value": 2.0,
#            "max_value": 4.5
#          }
#        },
#        "success": true,
#        "result": {
#          "element_count": 150,
#          "missing_count": 0,
#          "missing_percent": 0.0,
#          "unexpected_count": 0,
#          "unexpected_percent": 0.0,
#          "unexpected_percent_total": 0.0,
#          "unexpected_percent_nonmissing": 0.0,
#          "partial_unexpected_list": []
#        },
#        "meta": {},
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      }
#    ],
#    "meta": {
#      "great_expectations_version": "0.14.12",
#      "expectation_suite_name": "iris_dimensions",
#      "run_id": {
#        "run_time": "2022-12-19T18:34:59.890698+00:00",
#        "run_name": null
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "d8181756-7fcb-11ed-b0bc-002b67af4ef7"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20221219T183459.890621Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.14.12"
#      }
#    }
#  })
